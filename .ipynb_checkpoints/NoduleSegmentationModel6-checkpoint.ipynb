# %% [markdown]
# <a href="https://colab.research.google.com/github/x110/DLToolboxImg/blob/master/NoduleSegmentationModel6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Configuration

# %%
# Remove CUDA 9 completely

# !apt-get --purge remove cuda nvidia* libnvidia-*
# !dpkg -l | grep cuda- | awk '{print $2}' | xargs -n1 dpkg --purge
# !apt-get remove cuda-*
# !apt autoremove

# !apt-get update

# %%
# Install CUDA 8

# !wget https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1604/x86_64/cuda-repo-ubuntu1604_8.0.61-1_amd64.deb
# !dpkg -i --force-overwrite cuda-repo-ubuntu1604_8.0.61-1_amd64.deb
# !apt-get update
# !apt-get install cuda-8-0

# install will fail, need to force dpkg to overwrite the configuration file

# !wget http://archive.ubuntu.com/ubuntu/pool/main/m/mesa/libglx-mesa0_18.0.5-0ubuntu0~18.04.1_amd64.deb
# !dpkg -i --force-overwrite libglx-mesa0_18.0.5-0ubuntu0~18.04.1_amd64.deb

# !wget http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1604/x86_64/nvidia-410_410.48-0ubuntu1_amd64.deb
# !dpkg -i --force-overwrite nvidia-410_410.48-0ubuntu1_amd64.deb

# !apt --fix-broken install
# !apt-get install cuda-8-0

# %%
# !pip uninstall -y numpy

# %%
# !pip uninstall -y scipy

# %%
# !pip install turicreate
# The worng version of MXNET will be installed.
# !pip uninstall -y mxnet

# %%
# !pip install scipy

# %%
# Instal CUDA8-compatible version of mxnet 1.1.0
# !pip install mxnet-cu80==1.1.0

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !mkdir x110
# !mkdir x110/Datasets
# !mkdir x110/Datasets/Dataset5

# %%
#!rm -r 'x110/Datasets/Dataset5/processed/'

# %%
# !cp -a '/content/drive/My Drive/Datasets/Dataset5/processed/.' 'x110/Datasets/Dataset5/processed/'

# %%
# !mkdir x110/DLToolboxImg

# %%
# !git clone https://github.com/x110/DLToolboxImg.git x110/DLToolboxImg

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Nodule-Segmentation:-Model" data-toc-modified-id="Nodule-Segmentation:-Model-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Nodule Segmentation: Model</a></span><ul class="toc-item"><li><span><a href="#Preprocessing" data-toc-modified-id="Preprocessing-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Preprocessing</a></span><ul class="toc-item"><li><span><a href="#Find-mean-of-images" data-toc-modified-id="Find-mean-of-images-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Find mean of images</a></span></li><li><span><a href="#Find-variance-of-images" data-toc-modified-id="Find-variance-of-images-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>Find variance of images</a></span></li></ul></li><li><span><a href="#Data-Iterator" data-toc-modified-id="Data-Iterator-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Data Iterator</a></span></li><li><span><a href="#Evaluation-Metric" data-toc-modified-id="Evaluation-Metric-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Evaluation Metric</a></span></li><li><span><a href="#Model-Architecture" data-toc-modified-id="Model-Architecture-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Model Architecture</a></span></li><li><span><a href="#Optimizer" data-toc-modified-id="Optimizer-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Optimizer</a></span><ul class="toc-item"><li><span><a href="#Find--learning-rate" data-toc-modified-id="Find--learning-rate-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>Find  learning rate</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Nodule Segmentation: Model

# %%
import sys
sys.path.insert(0,"x110/DLToolboxImg/src/")

# %%
import mynnet7 as nn
import pickle
import mxnet as mx
import time
import matplotlib.pyplot as plt
import numpy as np

# %%
def dice_coef0(label, y):
    smooth = 1.
    intersection = mx.sym.sum(label * y)
    return (2. * intersection + smooth) / (mx.sym.sum(label) + mx.sym.sum(mx.sym.abs(y)) + smooth)
    return label*log(y)+(1-label)*log(1-p)

def logloss(label, y,w=[.9,.1]):
    eps=1e-15
    return mx.sym.mean(-(w[0]*label*mx.sym.log(y+eps)+w[1]*(1-label)*mx.sym.log(1-y+eps)))

# %%
#activation 0.4 crossentropy. train on pos and neg
def get_net_320():
    source = mx.sym.Variable("data")
    label = mx.sym.Variable("softmax_label")
    #print_inferred_shape(source)

    kernel_size = (3, 3, 3)
    stride=(1, 1,1)
    pad_size = (1, 1, 1)
    filter_count = 32
    net =  mx.sym.Convolution(data=source, kernel=kernel_size, stride=stride, pad=pad_size, num_filter=filter_count)
    net = mx.sym.BatchNorm(net)
    net = mx.sym.Activation(net, act_type="relu")
    #print_inferred_shape(net)
    
    
    net = mx.sym.Convolution(net, kernel=kernel_size, stride=stride, pad=pad_size, num_filter=filter_count)
    net = mx.sym.BatchNorm(net)
    net = mx.sym.Activation(net, act_type="relu")
    #print_inferred_shape(net)
    
    net = mx.sym.Convolution(net, kernel=kernel_size, stride=stride, pad=pad_size, num_filter=filter_count)
    net = mx.sym.BatchNorm(net)
    net = mx.sym.Activation(net, act_type="relu")
    #print_inferred_shape(net)
    
    net1=net
    
    net = mx.sym.Pooling(net, pool_type="max", kernel=(2, 2,2), stride=(2,2, 2))
    #print_inferred_shape(net)
    
    net = mx.sym.Convolution(net, kernel=kernel_size, stride=stride, pad=pad_size, num_filter=filter_count)
    net = mx.sym.BatchNorm(net)
    net = mx.sym.Activation(net, act_type="relu")

    #print_inferred_shape(net)

    
    net =  mx.sym.Convolution(net, kernel=kernel_size, stride=stride, pad=pad_size, num_filter=filter_count)
    net = mx.sym.BatchNorm(net)
    net = mx.sym.Activation(net, act_type="relu")
    #print_inferred_shape(net)
    
    net = mx.sym.Convolution(net, kernel=kernel_size, stride=stride, pad=pad_size, num_filter=filter_count)
    net = mx.sym.BatchNorm(net)
    net = mx.sym.Activation(net, act_type="relu")
    #print_inferred_shape(net)
    
    net = mx.sym.Dropout(net,p=0.6)
    
    net = mx.sym.Deconvolution(net, kernel=(2, 2,2), pad=(0, 0,0), stride=(2,2, 2), num_filter=filter_count)
    net = mx.sym.Activation(net, act_type="relu")


    
    net = mx.sym.Concat(*[net1, net])
    #print_inferred_shape(net)

    net = mx.sym.Convolution(net, kernel=kernel_size, stride=stride, pad=pad_size, num_filter=filter_count)
    net = mx.sym.BatchNorm(net)
    net = mx.sym.Activation(net, act_type="relu")
    #print_inferred_shape(net)
    
    net = mx.sym.Convolution(net, kernel=kernel_size, stride=stride, pad=pad_size, num_filter=filter_count)
    net = mx.sym.BatchNorm(net)
    net = mx.sym.Activation(net, act_type="relu")
    #print_inferred_shape(net)
        
    net = mx.sym.Convolution(net, kernel=kernel_size, stride=stride, pad=pad_size, num_filter=1)
    net = mx.sym.BatchNorm(net,fix_gamma=False)
    net = mx.sym.Activation(net, act_type="sigmoid")
    #print_inferred_shape(net)
    
    y = mx.symbol.Flatten(net)
    #y=mx.symbol.LogisticRegressionOutput(data=y, name='softmax')
    loss= mx.sym.MakeLoss(logloss(label, y))
    y = mx.sym.Group([mx.sym.BlockGrad(y), loss])

    return y

# %%
interm_dir4='x110/Datasets/Dataset5/' 
s = "2018_11_25"
train_data_path=interm_dir4+'processed/train'+s+'pos.rec'
train_idx_path=interm_dir4+'processed/train'+s+'pos.idx'
valid_data_path=interm_dir4+'processed/valid'+s+'pos.rec'
valid_idx_path=interm_dir4+'processed/valid'+s+'pos.idx'
test_data_path=interm_dir4+'processed/test'+s+'pos.rec'
test_idx_path=interm_dir4+'processed/test'+s+'pos.idx'

# %%
find_stats = False#True
bs = 100#64#34
load_model = False
model_path = "drive/My Drive/x110/model/dec02"
model_epoch=415
prefix = "drive/My Drive/x110/model/dec04model6"

# %%
#!cp  "drive/My Drive/x110/model/dec02-0415.params" x110/model/dec02-0415.params

# %%
#!cp "drive/My Drive/x110/model/dec02-0415-symbol.json" x110/model/

# %%
epochs = 10

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Find mean of images

# %%
if find_stats:
    BATCH_SIZE=1
    train_iter=nn.FileIter(train_data_path,train_idx_path,batch_size=BATCH_SIZE,do_augment=True,mean_image=0,std_image=1)
    train_iter.reset()
    x_mean = np.zeros((32,32,32))
    for i,batch in enumerate(train_iter):
        X =  batch.data[0][0][0].asnumpy()
        x_mean+=X
    x_mean=np.mean(x_mean/i)
    # Saving the objects:
    with open(interm_dir4+'processed/x_mean.pkl', 'wb') as f:  # Python 3: open(..., 'wb')
        pickle.dump([x_mean], f)

else:
    with open(interm_dir4+'processed/x_mean.pkl','rb') as f:  # Python 3: open(..., 'rb')
        x_mean = pickle.load(f)
x_mean#x_mean=0.2826227159416579
# Out:
# [0.28262271594165789]

# %%
x_mean=0.28

# %% [markdown]
# ### Find variance of images

# %%
if find_stats: 
    BATCH_SIZE=1
    train_iter=nn.FileIter(train_data_path,train_idx_path,batch_size=BATCH_SIZE,do_augment=True,mean_image=0,std_image = 1)
    train_iter.reset()
    x_var = np.zeros((32,32,32))
    for i,batch in enumerate(train_iter):
        X =  (batch.data[0][0][0].asnumpy()-x_mean)**2
        x_var+=X
    #x_var=x_var/(i-1)
    #x_var#x_mean=.2815
    N = i*32*32*32
    x_var = np.sum(x_var)/(N-1)
    x_var#x_var = .07877
    x_std = np.sqrt(x_var)#x_std=.2807
    with open(interm_dir4+'processed/x_std.pkl', 'wb') as f:  # Python 3: open(..., 'wb')
        pickle.dump([x_std], f)
else:
    with open(interm_dir4+'processed/x_std.pkl','rb') as f:  # Python 3: open(..., 'rb')
        x_std = pickle.load(f)
x_std#x_std=0.2817920662435274
# Out:
# [0.28179206624352737]

# %%
x_std = 0.28

# %% [markdown]
# ## Data Iterator

# %%
BATCH_SIZE=bs
train_iter=nn.FileIter(train_data_path,train_idx_path,batch_size=BATCH_SIZE,random_flip=True,do_augment=False,mean_image=x_mean,std_image = x_std,do_shuffle=True)
input_shapes = dict(train_iter.provide_data+train_iter.provide_label)
print(input_shapes)
# Out:
# {'data': (100, 1, 32, 32, 32), 'softmax_label': (100, 32768)}

# %%
BATCH_SIZE=bs
valid_iter=nn.FileIter(valid_data_path,valid_idx_path,batch_size=BATCH_SIZE,do_augment=False,mean_image=x_mean,std_image = x_std,do_shuffle=False)

# %%
train_iter.reset()
valid_iter.reset()

# %% [markdown]
# ## Evaluation Metric

# %%
def dice_coef2(label, y):
    smooth = 1.
    label=mx.nd.array(label).as_in_context(mx.gpu(0))
    y=mx.nd.array(y).as_in_context(mx.gpu(0))
    intersection = mx.nd.sum(label*y)
    return ((2. * intersection + smooth) / (mx.nd.sum(label) +mx.nd.sum(mx.nd.abs(y)) + smooth))

# %%
def logloss2(label, y,w=[.9,.1]):
    smooth = 1.
    label=mx.nd.array(label).as_in_context(mx.gpu(0))
    y=mx.nd.array(y).as_in_context(mx.gpu(0))
    eps=1e-12
    return mx.nd.mean(-(w[0]*label*mx.nd.log(y+eps)+w[1]*(1-label)*mx.nd.log(1-y+eps)))

# %%
eval_metrics_1 =  mx.metric.CustomMetric(feval=logloss2)
eval_metrics_2 = mx.metric.CustomMetric(feval=nn.dice_coef2)
metric= mx.metric.CompositeEvalMetric()
for child_metric in [eval_metrics_2, eval_metrics_1]:
  metric.add(child_metric)

# %% [markdown]
# ## Model Architecture

# %%
load_model
# Out:
# False

# %%
if load_model:
    network, arg_params, aux_params = mx.model.load_checkpoint(model_path , model_epoch)

    # Binding
    exe = network.simple_bind(ctx=mx.gpu(0), **input_shapes)


    exe.copy_params_from(arg_params, aux_params)
    
    # get handle to input arrays
    arg_arrays = dict(zip(network.list_arguments(), exe.arg_arrays))
    data = arg_arrays[train_iter.provide_data[0][0]]
    label = arg_arrays[train_iter.provide_label[0][0]]
else:

    network = get_net_320()
    init = mx.init.Normal(0.01) #note biases and gamma/beta are not affected

    # Binding
    exe = network.simple_bind(ctx=mx.gpu(), **input_shapes)
    # get handle to input arrays
    arg_arrays = dict(zip(network.list_arguments(), exe.arg_arrays))
    data = arg_arrays[train_iter.provide_data[0][0]]
    label = arg_arrays[train_iter.provide_label[0][0]]
    for name, arr in arg_arrays.items():
        if name not in input_shapes:
            init(name, arr)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:27: DeprecationWarning: Calling initializer with init(str, NDArray) has been deprecated.please use init(mx.init.InitDesc(...), NDArray) instead.

# %% [markdown]
# ## Optimizer

# %% [markdown]
# ### Find  learning rate

# %%
nb=train_iter.num_data//train_iter.batch_size
nb
# Out:
# 26

# %%
lrs = []
loss = []

# %%
sched=nn.lr_find(1e-4,nb,end_lr=1e-3)
# We also need to create an optimizer for updating weights
opt = mx.optimizer.SGD(
    learning_rate=1e-4,
    momentum=0.9,
    wd=0.00001,
    lr_scheduler=sched)

updater = mx.optimizer.get_updater(opt)
for epoch in range(0,1):

    start = time.time()

    metric.reset()

    train_iter.reset()
    
    valid_iter.reset()
    
    sched.reset()
        
    sched.on_train_begin()
    

    for batch in train_iter:
        # Copy data to executor input. Note the [:].
        data[:] = batch.data[0]
        label[:] = batch.label[0]

        # Forward
        outputs=exe.forward(is_train=True)
        # Backward
        exe.backward()

        # Update
        for i, pair in enumerate(zip(exe.arg_arrays, exe.grad_arrays)):
            weight, grad = pair
            updater(i, grad, weight)   
        #metric.update(batch.label[0], exe.outputs[0])#
        metric.update(batch.label[0], exe.outputs[0])
        
        e=metric.get()
        err_train=-e[1][0].asnumpy()[0]
        sched.on_batch_end(err_train)
    
    if epoch % 100== 0:       
        #print("do_checkpoint")
        arg={k:v for k, v in arg_arrays.items() if k not in input_shapes}
        aux = dict(zip(network.list_auxiliary_states(), exe.aux_arrays))
        mx.model.save_checkpoint(prefix, epoch, network, arg, aux)
        
        
    #compute valid loss per epoch    
    metric.reset()
    for batch in valid_iter:        
        data[:] = batch.data[0]       
        label[:] = batch.label[0]
        # predict
        outputs = exe.forward(is_train=False)
        metric.update(batch.label[0], exe.outputs[0])
    e=metric.get()
    err_valid=-e[1][0].asnumpy()[0]
    end = time.time()
    print('time:',end-start,'Epoch:',epoch,'trainloss:',err_train,'validloss:',err_valid,'CE',outputs[1].asnumpy())
    for x,y in zip(e[0],e[1]):
      print(x,y[0].asnumpy()[0], end=", ", flush=True)
plt.plot(sched.lrs, sched.losses,'*-')
# Out:
# time: 119.4135205745697 Epoch: 0 trainloss: -0.186856 validloss: -0.180081 CE [ 0.08964445]
# dice_coef2 0.180081, logloss2 0.071306,

# %%
lrs.extend(sched.lrs)
loss.extend(sched.losses)

# %%
sched=nn.lr_find(1e-3,nb,end_lr=1e-2)
# We also need to create an optimizer for updating weights
opt = mx.optimizer.SGD(
    learning_rate=1e-3,
    momentum=0.9,
    wd=0.00001,
    lr_scheduler=sched)

updater = mx.optimizer.get_updater(opt)
for epoch in range(0,1):

    start = time.time()

    metric.reset()

    train_iter.reset()
    
    valid_iter.reset()
    
    sched.reset()
        
    sched.on_train_begin()
    

    for batch in train_iter:
        # Copy data to executor input. Note the [:].
        data[:] = batch.data[0]
        label[:] = batch.label[0]

        # Forward
        outputs=exe.forward(is_train=True)
        # Backward
        exe.backward()

        # Update
        for i, pair in enumerate(zip(exe.arg_arrays, exe.grad_arrays)):
            weight, grad = pair
            updater(i, grad, weight)   
        #metric.update(batch.label[0], exe.outputs[0])#
        metric.update(batch.label[0], exe.outputs[0])
        
        e=metric.get()
        err_train=-e[1][0].asnumpy()[0]
        sched.on_batch_end(err_train)
    
    if epoch % 100== 0:       
        #print("do_checkpoint")
        arg={k:v for k, v in arg_arrays.items() if k not in input_shapes}
        aux = dict(zip(network.list_auxiliary_states(), exe.aux_arrays))
        mx.model.save_checkpoint(prefix, epoch, network, arg, aux)
        
        
    #compute valid loss per epoch    
    metric.reset()
    for batch in valid_iter:        
        data[:] = batch.data[0]       
        label[:] = batch.label[0]
        # predict
        outputs = exe.forward(is_train=False)
        metric.update(batch.label[0], exe.outputs[0])
    e=metric.get()
    err_valid=-e[1][0].asnumpy()[0]
    end = time.time()
    print('time:',end-start,'Epoch:',epoch,'trainloss:',err_train,'validloss:',err_valid,'CE',outputs[1].asnumpy())
    for x,y in zip(e[0],e[1]):
      print(x,y[0].asnumpy()[0], end=", ", flush=True)
lrs.extend(sched.lrs)
loss.extend(sched.losses)
plt.plot(lrs, loss,'*-')
# Out:
# time: 119.40084099769592 Epoch: 0 trainloss: -0.18713 validloss: -0.181336 CE [ 0.08930401]
# dice_coef2 0.181336, logloss2 0.0708793,

# %%
sched=nn.lr_find(1e-2,nb,end_lr=1e-1)
# We also need to create an optimizer for updating weights
opt = mx.optimizer.SGD(
    learning_rate=1e-2,
    momentum=0.9,
    wd=0.00001,
    lr_scheduler=sched)

updater = mx.optimizer.get_updater(opt)
for epoch in range(0,1):

    start = time.time()

    metric.reset()

    train_iter.reset()
    
    valid_iter.reset()
    
    sched.reset()
        
    sched.on_train_begin()
    

    for batch in train_iter:
        # Copy data to executor input. Note the [:].
        data[:] = batch.data[0]
        label[:] = batch.label[0]

        # Forward
        outputs=exe.forward(is_train=True)
        # Backward
        exe.backward()

        # Update
        for i, pair in enumerate(zip(exe.arg_arrays, exe.grad_arrays)):
            weight, grad = pair
            updater(i, grad, weight)   
        #metric.update(batch.label[0], exe.outputs[0])#
        metric.update(batch.label[0], exe.outputs[0])
        
        e=metric.get()
        err_train=-e[1][0].asnumpy()[0]
        sched.on_batch_end(err_train)
    
    if epoch % 100== 0:       
        #print("do_checkpoint")
        arg={k:v for k, v in arg_arrays.items() if k not in input_shapes}
        aux = dict(zip(network.list_auxiliary_states(), exe.aux_arrays))
        mx.model.save_checkpoint(prefix, epoch, network, arg, aux)
        
        
    #compute valid loss per epoch    
    metric.reset()
    for batch in valid_iter:        
        data[:] = batch.data[0]       
        label[:] = batch.label[0]
        # predict
        outputs = exe.forward(is_train=False)
        metric.update(batch.label[0], exe.outputs[0])
    e=metric.get()
    err_valid=-e[1][0].asnumpy()[0]
    end = time.time()
    print('time:',end-start,'Epoch:',epoch,'trainloss:',err_train,'validloss:',err_valid,'CE',outputs[1].asnumpy())
    for x,y in zip(e[0],e[1]):
      print(x,y[0].asnumpy()[0], end=", ", flush=True)
lrs.extend(sched.lrs)
loss.extend(sched.losses)
plt.plot(lrs, loss,'*-')
# Out:
# time: 119.3840115070343 Epoch: 0 trainloss: -0.18726 validloss: -0.181218 CE [ 0.08873864]
# dice_coef2 0.181218, logloss2 0.0698071,

# %%
sched=nn.lr_find(1e-1,nb,end_lr=1)
# We also need to create an optimizer for updating weights
opt = mx.optimizer.SGD(
    learning_rate=1e-1,
    momentum=0.9,
    wd=0.00001,
    lr_scheduler=sched)

updater = mx.optimizer.get_updater(opt)
for epoch in range(0,1):

    start = time.time()

    metric.reset()

    train_iter.reset()
    
    valid_iter.reset()
    
    sched.reset()
        
    sched.on_train_begin()
    

    for batch in train_iter:
        # Copy data to executor input. Note the [:].
        data[:] = batch.data[0]
        label[:] = batch.label[0]

        # Forward
        outputs=exe.forward(is_train=True)
        # Backward
        exe.backward()

        # Update
        for i, pair in enumerate(zip(exe.arg_arrays, exe.grad_arrays)):
            weight, grad = pair
            updater(i, grad, weight)   
        #metric.update(batch.label[0], exe.outputs[0])#
        metric.update(batch.label[0], exe.outputs[0])
        
        e=metric.get()
        err_train=-e[1][0].asnumpy()[0]
        sched.on_batch_end(err_train)
    
    if epoch % 100== 0:       
        #print("do_checkpoint")
        arg={k:v for k, v in arg_arrays.items() if k not in input_shapes}
        aux = dict(zip(network.list_auxiliary_states(), exe.aux_arrays))
        mx.model.save_checkpoint(prefix, epoch, network, arg, aux)
        
        
    #compute valid loss per epoch    
    metric.reset()
    for batch in valid_iter:        
        data[:] = batch.data[0]       
        label[:] = batch.label[0]
        # predict
        outputs = exe.forward(is_train=False)
        metric.update(batch.label[0], exe.outputs[0])
    e=metric.get()
    err_valid=-e[1][0].asnumpy()[0]
    end = time.time()
    print('time:',end-start,'Epoch:',epoch,'trainloss:',err_train,'validloss:',err_valid,'CE',outputs[1].asnumpy())
    for x,y in zip(e[0],e[1]):
      print(x,y[0].asnumpy()[0], end=", ", flush=True)
lrs.extend(sched.lrs)
loss.extend(sched.losses)
plt.plot(lrs, loss,'*-')
# Out:
# time: 119.38993287086487 Epoch: 0 trainloss: -0.18823 validloss: -0.161116 CE [ 0.10687938]
# dice_coef2 0.161116, logloss2 0.107985,

# %%
plt.plot(lrs[:30], loss[:30],'*-')

# %%
lrs[2:4]
# Out:
# [0.0001153846153846154, 0.00015384615384615385]

# %%
plt.plot(lrs[25:40], loss[25:40],'*-')

# %%
lrs[29]
# Out:
# 0.0015384615384615387

# %%
0.0001

# %%
epochs = 20

# %%
# We also need to create an optimizer for updating weights
# ===============Optimizer=================                        
opt = mx.optimizer.SGD(
    learning_rate=.0001,momentum=0.99,wd=0.000001)
updater = mx.optimizer.get_updater(opt)
updater.optimizer.lr_scheduler=None

# %%
epoch_r  = 0
epoch_r
Es_train=[]
Es_valid=[]
for epoch in range(epoch_r,epoch_r+epochs+1):

    start = time.time()

    metric.reset()

    train_iter.reset()
    
    valid_iter.reset()
    

    for batch in train_iter:
        # Copy data to executor input. Note the [:].
        data[:] = batch.data[0]
        label[:] = batch.label[0]

        # Forward
        outputs=exe.forward(is_train=True)
        Es_train.append(outputs[1].asnumpy()[0])
        # Backward
        exe.backward()

        # Update
        for i, pair in enumerate(zip(exe.arg_arrays, exe.grad_arrays)):
            weight, grad = pair
            updater(i, grad, weight)   
        metric.update(batch.label[0], exe.outputs[0])#metric.update(label,p)
        
    e=metric.get()
    err_train=-e[1][0].asnumpy()[0]
    err_train2=-e[1][1].asnumpy()[0]
    
    if epoch % 10== 0:       
        #print("do_checkpoint")
        arg={k:v for k, v in arg_arrays.items() if k not in input_shapes}
        aux = dict(zip(network.list_auxiliary_states(), exe.aux_arrays))
        mx.model.save_checkpoint(prefix, epoch, network, arg, aux)
        
        
    #compute valid loss per epoch    
    metric.reset()
    for batch in valid_iter:        
        data[:] = batch.data[0]       
        label[:] = batch.label[0]
        # predict
        outputs = exe.forward(is_train=False)
        Es_valid.append(outputs[1].asnumpy()[0])
        metric.update(batch.label[0], exe.outputs[0])
    e=metric.get()
    err_valid=-e[1][0].asnumpy()[0]
    err_valid2=-e[1][1].asnumpy()[0]
    end = time.time()
    print('time:',end-start,'Epoch:',epoch,'trainloss:',err_train,'validloss:',err_valid,'trainloss2:',err_train2,'validloss2:',err_valid2)
    #print('time:',end-start,'Epoch:',epoch,'trainloss:',err_train,'validloss:',err_valid,'trainloss2',outputs[1].asnumpy())

    #print('time:',end-start,'Epoch:',epoch,'trainloss:',err_train,'validloss:',err_valid)
    #for x,y in zip(e[0],e[1]):
      #print(x,y[0].asnumpy()[0], end=", ", flush=True)
# Out:
# time: 110.72973680496216 Epoch: 0 trainloss: -0.188145 validloss: -0.180357 trainloss2: -0.0649547 validloss2: -0.0689325
# time: 110.62401247024536 Epoch: 1 trainloss: -0.188872 validloss: -0.183519 trainloss2: -0.0645923 validloss2: -0.0681674
# time: 110.55216550827026 Epoch: 2 trainloss: -0.188784 validloss: -0.18437 trainloss2: -0.0647248 validloss2: -0.0677994
# time: 110.4866828918457 Epoch: 3 trainloss: -0.189581 validloss: -0.184916 trainloss2: -0.0639763 validloss2: -0.0674153
# time: 110.44334745407104 Epoch: 4 trainloss: -0.190167 validloss: -0.185278 trainloss2: -0.0636623 validloss2: -0.0671011
# time: 110.55575370788574 Epoch: 5 trainloss: -0.190268 validloss: -0.185701 trainloss2: -0.0634642 validloss2: -0.0668202
# time: 110.6107611656189 Epoch: 6 trainloss: -0.190759 validloss: -0.186081 trainloss2: -0.0635036 validloss2: -0.0666215
# time: 110.60577869415283 Epoch: 7 trainloss: -0.191182 validloss: -0.186062 trainloss2: -0.063197 validloss2: -0.0664335
# time: 110.40333366394043 Epoch: 8 trainloss: -0.191105 validloss: -0.185855 trainloss2: -0.0630719 validloss2: -0.0663495
# time: 110.53763723373413 Epoch: 9 trainloss: -0.191416 validloss: -0.186266 trainloss2: -0.0631163 validloss2: -0.0662963
# time: 110.45313143730164 Epoch: 10 trainloss: -0.191539 validloss: -0.185991 trainloss2: -0.0628549 validloss2: -0.0662174
# time: 110.44575715065002 Epoch: 11 trainloss: -0.191725 validloss: -0.186338 trainloss2: -0.0630829 validloss2: -0.0661526
# time: 110.454763174057 Epoch: 12 trainloss: -0.191614 validloss: -0.186345 trainloss2: -0.0628243 validloss2: -0.0661317
# time: 110.51651906967163 Epoch: 13 trainloss: -0.192026 validloss: -0.186553 trainloss2: -0.0626588 validloss2: -0.0660986
# time: 110.38124680519104 Epoch: 14 trainloss: -0.192121 validloss: -0.186344 trainloss2: -0.0627113 validloss2: -0.0660857
# time: 110.54740071296692 Epoch: 15 trainloss: -0.192239 validloss: -0.186696 trainloss2: -0.0625533 validloss2: -0.0660762
# time: 110.3765652179718 Epoch: 16 trainloss: -0.192288 validloss: -0.186577 trainloss2: -0.0626323 validloss2: -0.0660445
# time: 110.456463098526 Epoch: 17 trainloss: -0.192733 validloss: -0.186641 trainloss2: -0.0622811 validloss2: -0.0660589
# time: 110.61432075500488 Epoch: 18 trainloss: -0.19227 validloss: -0.186412 trainloss2: -0.062663 validloss2: -0.0660735
# time: 110.41517806053162 Epoch: 19 trainloss: -0.192239 validloss: -0.186593 trainloss2: -0.0627037 validloss2: -0.0660328
# time: 110.63813471794128 Epoch: 20 trainloss: -0.192499 validloss: -0.186629 trainloss2: -0.0624635 validloss2: -0.0660516

# %%
#Es_valid3=[]
#Es_train3=[]
nb2 = valid_iter.num_data//valid_iter.batch_size

# %%
#plot the loss over epoch
Es_train = np.array(Es_train)
Es_train2 = Es_train.reshape((-1,nb))
Es_train3.extend([e for e in list(np.mean(Es_train2,axis=1))])
plt.plot(Es_train3,'.-')
#plot the loss over epoch
Es_valid = np.array(Es_valid)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-faf8530bdec9> in <module>()
#       5 #plot the loss over epoch
#       6 Es_valid = np.array(Es_valid)
# ----> 7 Es_valid2 = Es_valid.reshape((-1,nb2))
#       8 Es_valid3.extend([e for e in list(np.mean(Es_valid2,axis=1))])
#       9 plt.figure()
#
# NameError: name 'nb2' is not defined

# %%
Es_valid2 = Es_valid.reshape((-1,nb2))
Es_valid3.extend([e for e in list(np.mean(Es_valid2,axis=1))])
plt.figure()
plt.plot(Es_valid3,'.-r')
plt.figure()
plt.plot(Es_train3,'.-')
plt.plot(Es_valid3,'.-r')

# %%
lrs = []
loss = []
sched=nn.lr_find(1e-4,nb,end_lr=1e-3)
# We also need to create an optimizer for updating weights
opt = mx.optimizer.SGD(
    learning_rate=1e-4,
    momentum=0.9,
    wd=0.00001,
    lr_scheduler=sched)

updater = mx.optimizer.get_updater(opt)
for epoch in range(0,1):

    start = time.time()

    metric.reset()

    train_iter.reset()
    
    valid_iter.reset()
    
    sched.reset()
        
    sched.on_train_begin()
    

    for batch in train_iter:
        # Copy data to executor input. Note the [:].
        data[:] = batch.data[0]
        label[:] = batch.label[0]

        # Forward
        outputs=exe.forward(is_train=True)
        # Backward
        exe.backward()

        # Update
        for i, pair in enumerate(zip(exe.arg_arrays, exe.grad_arrays)):
            weight, grad = pair
            updater(i, grad, weight)   
        #metric.update(batch.label[0], exe.outputs[0])#
        metric.update(batch.label[0], exe.outputs[0])
        
        e=metric.get()
        err_train=-e[1][0].asnumpy()[0]
        sched.on_batch_end(err_train)
    
    if epoch % 100== 0:       
        #print("do_checkpoint")
        arg={k:v for k, v in arg_arrays.items() if k not in input_shapes}
        aux = dict(zip(network.list_auxiliary_states(), exe.aux_arrays))
        mx.model.save_checkpoint(prefix, epoch, network, arg, aux)
        
        
    #compute valid loss per epoch    
    metric.reset()
    for batch in valid_iter:        
        data[:] = batch.data[0]       
        label[:] = batch.label[0]
        # predict
        outputs = exe.forward(is_train=False)
        metric.update(batch.label[0], exe.outputs[0])
    e=metric.get()
    err_valid=-e[1][0].asnumpy()[0]
    end = time.time()
    print('time:',end-start,'Epoch:',epoch,'trainloss:',err_train,'validloss:',err_valid,'CE',outputs[1].asnumpy())
    for x,y in zip(e[0],e[1]):
      print(x,y[0].asnumpy()[0], end=", ", flush=True)
lrs.extend(sched.lrs)
loss.extend(sched.losses)













sched=nn.lr_find(1e-3,nb,end_lr=1e-2)
# We also need to create an optimizer for updating weights
opt = mx.optimizer.SGD(
    learning_rate=1e-3,
    momentum=0.9,
    wd=0.00001,
    lr_scheduler=sched)

updater = mx.optimizer.get_updater(opt)
for epoch in range(0,1):

    start = time.time()

    metric.reset()

    train_iter.reset()
    
    valid_iter.reset()
    
    sched.reset()
        
    sched.on_train_begin()
    

    for batch in train_iter:
        # Copy data to executor input. Note the [:].
        data[:] = batch.data[0]
        label[:] = batch.label[0]

        # Forward
        outputs=exe.forward(is_train=True)
        # Backward
        exe.backward()

        # Update
        for i, pair in enumerate(zip(exe.arg_arrays, exe.grad_arrays)):
            weight, grad = pair
            updater(i, grad, weight)   
        #metric.update(batch.label[0], exe.outputs[0])#
        metric.update(batch.label[0], exe.outputs[0])
        
        e=metric.get()
        err_train=-e[1][0].asnumpy()[0]
        sched.on_batch_end(err_train)
    
    if epoch % 100== 0:       
        #print("do_checkpoint")
        arg={k:v for k, v in arg_arrays.items() if k not in input_shapes}
        aux = dict(zip(network.list_auxiliary_states(), exe.aux_arrays))
        mx.model.save_checkpoint(prefix, epoch, network, arg, aux)
        
        
    #compute valid loss per epoch    
    metric.reset()
    for batch in valid_iter:        
        data[:] = batch.data[0]       
        label[:] = batch.label[0]
        # predict
        outputs = exe.forward(is_train=False)
        metric.update(batch.label[0], exe.outputs[0])
    e=metric.get()
    err_valid=-e[1][0].asnumpy()[0]
    end = time.time()
    print('time:',end-start,'Epoch:',epoch,'trainloss:',err_train,'validloss:',err_valid,'CE',outputs[1].asnumpy())
    for x,y in zip(e[0],e[1]):
      print(x,y[0].asnumpy()[0], end=", ", flush=True)
lrs.extend(sched.lrs)
loss.extend(sched.losses)
















sched=nn.lr_find(1e-2,nb,end_lr=1e-1)
# We also need to create an optimizer for updating weights
opt = mx.optimizer.SGD(
    learning_rate=1e-2,
    momentum=0.9,
    wd=0.00001,
    lr_scheduler=sched)

updater = mx.optimizer.get_updater(opt)
for epoch in range(0,1):

    start = time.time()

    metric.reset()

    train_iter.reset()
    
    valid_iter.reset()
    
    sched.reset()
        
    sched.on_train_begin()
    

    for batch in train_iter:
        # Copy data to executor input. Note the [:].
        data[:] = batch.data[0]
        label[:] = batch.label[0]

        # Forward
        outputs=exe.forward(is_train=True)
        # Backward
        exe.backward()

        # Update
        for i, pair in enumerate(zip(exe.arg_arrays, exe.grad_arrays)):
            weight, grad = pair
            updater(i, grad, weight)   
        #metric.update(batch.label[0], exe.outputs[0])#
        metric.update(batch.label[0], exe.outputs[0])
        
        e=metric.get()
        err_train=-e[1][0].asnumpy()[0]
        sched.on_batch_end(err_train)
    
    if epoch % 100== 0:       
        #print("do_checkpoint")
        arg={k:v for k, v in arg_arrays.items() if k not in input_shapes}
        aux = dict(zip(network.list_auxiliary_states(), exe.aux_arrays))
        mx.model.save_checkpoint(prefix, epoch, network, arg, aux)
        
        
    #compute valid loss per epoch    
    metric.reset()
    for batch in valid_iter:        
        data[:] = batch.data[0]       
        label[:] = batch.label[0]
        # predict
        outputs = exe.forward(is_train=False)
        metric.update(batch.label[0], exe.outputs[0])
    e=metric.get()
    err_valid=-e[1][0].asnumpy()[0]
    end = time.time()
    print('time:',end-start,'Epoch:',epoch,'trainloss:',err_train,'validloss:',err_valid,'CE',outputs[1].asnumpy())
    for x,y in zip(e[0],e[1]):
      print(x,y[0].asnumpy()[0], end=", ", flush=True)
lrs.extend(sched.lrs)
loss.extend(sched.losses)












sched=nn.lr_find(1e-1,nb,end_lr=1)
# We also need to create an optimizer for updating weights
opt = mx.optimizer.SGD(
    learning_rate=1e-1,
    momentum=0.9,
    wd=0.00001,
    lr_scheduler=sched)

updater = mx.optimizer.get_updater(opt)
for epoch in range(0,1):

    start = time.time()

    metric.reset()

    train_iter.reset()
    
    valid_iter.reset()
    
    sched.reset()
        
    sched.on_train_begin()
    

    for batch in train_iter:
        # Copy data to executor input. Note the [:].
        data[:] = batch.data[0]
        label[:] = batch.label[0]

        # Forward
        outputs=exe.forward(is_train=True)
        # Backward
        exe.backward()

        # Update
        for i, pair in enumerate(zip(exe.arg_arrays, exe.grad_arrays)):
            weight, grad = pair
            updater(i, grad, weight)   
        #metric.update(batch.label[0], exe.outputs[0])#
        metric.update(batch.label[0], exe.outputs[0])
        
        e=metric.get()
        err_train=-e[1][0].asnumpy()[0]
        sched.on_batch_end(err_train)
    
    if epoch % 100== 0:       
        #print("do_checkpoint")
        arg={k:v for k, v in arg_arrays.items() if k not in input_shapes}
        aux = dict(zip(network.list_auxiliary_states(), exe.aux_arrays))
        mx.model.save_checkpoint(prefix, epoch, network, arg, aux)
        
        
    #compute valid loss per epoch    
    metric.reset()
    for batch in valid_iter:        
        data[:] = batch.data[0]       
        label[:] = batch.label[0]
        # predict
        outputs = exe.forward(is_train=False)
        metric.update(batch.label[0], exe.outputs[0])
    e=metric.get()
    err_valid=-e[1][0].asnumpy()[0]
    end = time.time()
    print('time:',end-start,'Epoch:',epoch,'trainloss:',err_train,'validloss:',err_valid,'CE',outputs[1].asnumpy())
    for x,y in zip(e[0],e[1]):
      print(x,y[0].asnumpy()[0], end=", ", flush=True)
lrs.extend(sched.lrs)
loss.extend(sched.losses)




plt.plot(lrs, loss,'*-')
# Out:
# time: 119.38006973266602 Epoch: 0 trainloss: -0.192397 validloss: -0.186609 CE [ 0.08338097]
# dice_coef2 0.186609, logloss2 0.0660183, time: 119.34453558921814 Epoch: 0 trainloss: -0.192409 validloss: -0.187195 CE [ 0.0835622]
# dice_coef2 0.187195, logloss2 0.0660296, time: 119.30569171905518 Epoch: 0 trainloss: -0.193046 validloss: -0.189936 CE [ 0.08677391]
# dice_coef2 0.189936, logloss2 0.0670248, time: 119.40261125564575 Epoch: 0 trainloss: -0.194018 validloss: -0.19725 CE [ 0.09105668]
# dice_coef2 0.19725, logloss2 0.0696431,

# %%
plt.plot(lrs[:20], loss[:20],'*-')

# %%
  trainlosses=[]
  validlosses=[]
  trainlosses2=[]
  validlosses2=[]

# %%
# We also need to create an optimizer for updating weights
# ===============Optimizer=================                        
opt = mx.optimizer.SGD(
    learning_rate=.0003,momentum=0.99,wd=0.000001)
updater = mx.optimizer.get_updater(opt)
updater.optimizer.lr_scheduler=None

# %%
epoch_r  = 20
epoch_r
Es_train=[]
Es_valid=[]
for epoch in range(epoch_r,epoch_r+epochs+1):

    start = time.time()

    metric.reset()

    train_iter.reset()
    
    valid_iter.reset()
    

    for batch in train_iter:
        # Copy data to executor input. Note the [:].
        data[:] = batch.data[0]
        label[:] = batch.label[0]

        # Forward
        outputs=exe.forward(is_train=True)
        Es_train.append(outputs[1].asnumpy()[0])
        # Backward
        exe.backward()

        # Update
        for i, pair in enumerate(zip(exe.arg_arrays, exe.grad_arrays)):
            weight, grad = pair
            updater(i, grad, weight)   
        metric.update(batch.label[0], exe.outputs[0])#metric.update(label,p)
        
    e=metric.get()
    err_train=-e[1][0].asnumpy()[0]
    err_train2=-e[1][1].asnumpy()[0]
    
    if epoch % 10== 0:       
        #print("do_checkpoint")
        arg={k:v for k, v in arg_arrays.items() if k not in input_shapes}
        aux = dict(zip(network.list_auxiliary_states(), exe.aux_arrays))
        mx.model.save_checkpoint(prefix, epoch, network, arg, aux)
        
        
    #compute valid loss per epoch    
    metric.reset()
    for batch in valid_iter:        
        data[:] = batch.data[0]       
        label[:] = batch.label[0]
        # predict
        outputs = exe.forward(is_train=False)
        Es_valid.append(outputs[1].asnumpy()[0])
        metric.update(batch.label[0], exe.outputs[0])
    e=metric.get()
    err_valid=-e[1][0].asnumpy()[0]
    err_valid2=-e[1][1].asnumpy()[0]
    end = time.time()
    print('time:',end-start,'Epoch:',epoch,'trainloss:',err_train,'validloss:',err_valid,'trainloss2:',err_train2,'validloss2:',err_valid2)
    trainlosses.append(err_train)
    validlosses.append(err_valid)
    trainlosses2.append(err_train2)
    validlosses2.append(err_valid2)
    #print('time:',end-start,'Epoch:',epoch,'trainloss:',err_train,'validloss:',err_valid,'trainloss2',outputs[1].asnumpy())

    #print('time:',end-start,'Epoch:',epoch,'trainloss:',err_train,'validloss:',err_valid)
    #for x,y in zip(e[0],e[1]):
      #print(x,y[0].asnumpy()[0], end=", ", flush=True)
# Out:
# time: 110.60636281967163 Epoch: 20 trainloss: -0.198897 validloss: -0.193973 trainloss2: -0.0625243 validloss2: -0.065927
# time: 110.4740526676178 Epoch: 21 trainloss: -0.199484 validloss: -0.194191 trainloss2: -0.0623366 validloss2: -0.0654051
# time: 110.59115767478943 Epoch: 22 trainloss: -0.200305 validloss: -0.194668 trainloss2: -0.0613763 validloss2: -0.0648492
# time: 110.62772607803345 Epoch: 23 trainloss: -0.200986 validloss: -0.195282 trainloss2: -0.0609141 validloss2: -0.0649828
# time: 110.53694748878479 Epoch: 24 trainloss: -0.20168 validloss: -0.195733 trainloss2: -0.0609254 validloss2: -0.064807
# time: 110.45083618164062 Epoch: 25 trainloss: -0.201833 validloss: -0.196073 trainloss2: -0.0607466 validloss2: -0.064809
# time: 110.4436502456665 Epoch: 26 trainloss: -0.202391 validloss: -0.196523 trainloss2: -0.0603365 validloss2: -0.0648114
# time: 110.42857766151428 Epoch: 27 trainloss: -0.20244 validloss: -0.196392 trainloss2: -0.0601744 validloss2: -0.0649324
# time: 110.57096457481384 Epoch: 28 trainloss: -0.202597 validloss: -0.196492 trainloss2: -0.0603239 validloss2: -0.0648743
# time: 110.56386613845825 Epoch: 29 trainloss: -0.202701 validloss: -0.196776 trainloss2: -0.0601036 validloss2: -0.0646648
# time: 110.48829960823059 Epoch: 30 trainloss: -0.202488 validloss: -0.197048 trainloss2: -0.0601435 validloss2: -0.0644268
# time: 110.41210675239563 Epoch: 31 trainloss: -0.202797 validloss: -0.197078 trainloss2: -0.0599921 validloss2: -0.0641784
# time: 110.4783308506012 Epoch: 32 trainloss: -0.202937 validloss: -0.196749 trainloss2: -0.0594929 validloss2: -0.0639939
# time: 110.5214831829071 Epoch: 33 trainloss: -0.202569 validloss: -0.19697 trainloss2: -0.0600429 validloss2: -0.0639264
# time: 110.48943305015564 Epoch: 34 trainloss: -0.202814 validloss: -0.196434 trainloss2: -0.0595064 validloss2: -0.063783
# time: 110.51974678039551 Epoch: 35 trainloss: -0.203014 validloss: -0.196787 trainloss2: -0.059746 validloss2: -0.0637056
# time: 110.54715037345886 Epoch: 36 trainloss: -0.202707 validloss: -0.19731 trainloss2: -0.0597227 validloss2: -0.0635539
# time: 110.62224626541138 Epoch: 37 trainloss: -0.202759 validloss: -0.19659 trainloss2: -0.0594176 validloss2: -0.0636958
# time: 110.55898070335388 Epoch: 38 trainloss: -0.203137 validloss: -0.19661 trainloss2: -0.0591516 validloss2: -0.0634419
# time: 110.53115773200989 Epoch: 39 trainloss: -0.202864 validloss: -0.196944 trainloss2: -0.0594498 validloss2: -0.0635384
# time: 110.61438822746277 Epoch: 40 trainloss: -0.202715 validloss: -0.197261 trainloss2: -0.0595834 validloss2: -0.0634286

# %%
#plot the loss over epoch
Es_train = np.array(Es_train)
Es_train2 = Es_train.reshape((-1,nb))
Es_train3.extend([e for e in list(np.mean(Es_train2,axis=1))])
plt.plot(Es_train3,'.-')
#plot the loss over epoch
Es_valid = np.array(Es_valid)
Es_valid2 = Es_valid.reshape((-1,nb2))
Es_valid3.extend([e for e in list(np.mean(Es_valid2,axis=1))])
plt.figure()
plt.plot(Es_valid3,'.-r')
plt.figure()
plt.plot(Es_train3,'.-')
plt.plot(Es_valid3,'.-r')

# %%
plt.plot(trainlosses,'.-')
plt.plot(validlosses,'.-r')
plt.figure()
plt.plot(trainlosses2,'.-')
plt.plot(validlosses2,'.-r')

# %%
epoch_r  = 40
epoch_r
Es_train=[]
Es_valid=[]
for epoch in range(epoch_r,epoch_r+epochs+1):

    start = time.time()

    metric.reset()

    train_iter.reset()
    
    valid_iter.reset()
    

    for batch in train_iter:
        # Copy data to executor input. Note the [:].
        data[:] = batch.data[0]
        label[:] = batch.label[0]

        # Forward
        outputs=exe.forward(is_train=True)
        Es_train.append(outputs[1].asnumpy()[0])
        # Backward
        exe.backward()

        # Update
        for i, pair in enumerate(zip(exe.arg_arrays, exe.grad_arrays)):
            weight, grad = pair
            updater(i, grad, weight)   
        metric.update(batch.label[0], exe.outputs[0])#metric.update(label,p)
        
    e=metric.get()
    err_train=-e[1][0].asnumpy()[0]
    err_train2=-e[1][1].asnumpy()[0]
    
    if epoch % 10== 0:       
        #print("do_checkpoint")
        arg={k:v for k, v in arg_arrays.items() if k not in input_shapes}
        aux = dict(zip(network.list_auxiliary_states(), exe.aux_arrays))
        mx.model.save_checkpoint(prefix, epoch, network, arg, aux)
        
        
    #compute valid loss per epoch    
    metric.reset()
    for batch in valid_iter:        
        data[:] = batch.data[0]       
        label[:] = batch.label[0]
        # predict
        outputs = exe.forward(is_train=False)
        Es_valid.append(outputs[1].asnumpy()[0])
        metric.update(batch.label[0], exe.outputs[0])
    e=metric.get()
    err_valid=-e[1][0].asnumpy()[0]
    err_valid2=-e[1][1].asnumpy()[0]
    end = time.time()
    print('time:',end-start,'Epoch:',epoch,'trainloss:',err_train,'validloss:',err_valid,'trainloss2:',err_train2,'validloss2:',err_valid2)
    trainlosses.append(err_train)
    validlosses.append(err_valid)
    trainlosses2.append(err_train2)
    validlosses2.append(err_valid2)
    #print('time:',end-start,'Epoch:',epoch,'trainloss:',err_train,'validloss:',err_valid,'trainloss2',outputs[1].asnumpy())

    #print('time:',end-start,'Epoch:',epoch,'trainloss:',err_train,'validloss:',err_valid)
    #for x,y in zip(e[0],e[1]):
      #print(x,y[0].asnumpy()[0], end=", ", flush=True)
# Out:
# time: 110.56976819038391 Epoch: 40 trainloss: -0.202669 validloss: -0.197237 trainloss2: -0.0596291 validloss2: -0.0635095
# time: 110.62681436538696 Epoch: 41 trainloss: -0.203113 validloss: -0.197064 trainloss2: -0.0590536 validloss2: -0.0634162
# time: 110.48542833328247 Epoch: 42 trainloss: -0.203002 validloss: -0.196867 trainloss2: -0.0594634 validloss2: -0.0633101
# time: 110.50899815559387 Epoch: 43 trainloss: -0.203461 validloss: -0.197272 trainloss2: -0.0589641 validloss2: -0.0631817
# time: 110.59089303016663 Epoch: 44 trainloss: -0.203269 validloss: -0.197171 trainloss2: -0.0591113 validloss2: -0.063098
# time: 110.57278800010681 Epoch: 45 trainloss: -0.203219 validloss: -0.197542 trainloss2: -0.0589037 validloss2: -0.0631824
# time: 110.54819655418396 Epoch: 46 trainloss: -0.203199 validloss: -0.196948 trainloss2: -0.0592562 validloss2: -0.0630719
# time: 110.5715582370758 Epoch: 47 trainloss: -0.203715 validloss: -0.19754 trainloss2: -0.0588292 validloss2: -0.0629998
# time: 110.53351902961731 Epoch: 48 trainloss: -0.203686 validloss: -0.197888 trainloss2: -0.0586436 validloss2: -0.062936
# time: 110.62484502792358 Epoch: 49 trainloss: -0.20362 validloss: -0.197892 trainloss2: -0.0587493 validloss2: -0.0629699
# time: 110.63795804977417 Epoch: 50 trainloss: -0.203321 validloss: -0.19813 trainloss2: -0.0590959 validloss2: -0.0628704
# time: 110.51893901824951 Epoch: 51 trainloss: -0.203937 validloss: -0.197728 trainloss2: -0.0584028 validloss2: -0.0628723
# time: 110.5462338924408 Epoch: 52 trainloss: -0.203708 validloss: -0.197757 trainloss2: -0.0588227 validloss2: -0.062836
# time: 110.59837865829468 Epoch: 53 trainloss: -0.203829 validloss: -0.198373 trainloss2: -0.0587084 validloss2: -0.062874
# time: 110.65161681175232 Epoch: 54 trainloss: -0.204177 validloss: -0.198039 trainloss2: -0.0583644 validloss2: -0.0626432
# time: 110.6077470779419 Epoch: 55 trainloss: -0.204105 validloss: -0.198024 trainloss2: -0.058635 validloss2: -0.0626418
# time: 110.54584169387817 Epoch: 56 trainloss: -0.203972 validloss: -0.198143 trainloss2: -0.0588567 validloss2: -0.0626681
# time: 110.5569314956665 Epoch: 57 trainloss: -0.204104 validloss: -0.198501 trainloss2: -0.0585404 validloss2: -0.0624805
# time: 110.63001275062561 Epoch: 58 trainloss: -0.204069 validloss: -0.198345 trainloss2: -0.0584628 validloss2: -0.0625752
# time: 110.65774941444397 Epoch: 59 trainloss: -0.204397 validloss: -0.198586 trainloss2: -0.0584737 validloss2: -0.0625053
# time: 110.65177798271179 Epoch: 60 trainloss: -0.204187 validloss: -0.199071 trainloss2: -0.0587296 validloss2: -0.0625066

# %%
#plot the loss over epoch
Es_train = np.array(Es_train)
Es_train2 = Es_train.reshape((-1,nb))
Es_train3.extend([e for e in list(np.mean(Es_train2,axis=1))])
#plot the loss over epoch
Es_valid = np.array(Es_valid)
Es_valid2 = Es_valid.reshape((-1,nb2))
Es_valid3.extend([e for e in list(np.mean(Es_valid2,axis=1))])
plt.figure()
plt.plot(Es_train3,'.-')
plt.plot(Es_valid3,'.-r')

# %%
plt.figure()
plt.plot(trainlosses2,'.-')
plt.plot(validlosses2,'.-r')

# %%
epoch_r  = 60
epoch_r
Es_train=[]
Es_valid=[]
for epoch in range(epoch_r,epoch_r+epochs+1):

    start = time.time()

    metric.reset()

    train_iter.reset()
    
    valid_iter.reset()
    

    for batch in train_iter:
        # Copy data to executor input. Note the [:].
        data[:] = batch.data[0]
        label[:] = batch.label[0]

        # Forward
        outputs=exe.forward(is_train=True)
        Es_train.append(outputs[1].asnumpy()[0])
        # Backward
        exe.backward()

        # Update
        for i, pair in enumerate(zip(exe.arg_arrays, exe.grad_arrays)):
            weight, grad = pair
            updater(i, grad, weight)   
        metric.update(batch.label[0], exe.outputs[0])#metric.update(label,p)
        
    e=metric.get()
    err_train=-e[1][0].asnumpy()[0]
    err_train2=-e[1][1].asnumpy()[0]
    
    if epoch % 10== 0:       
        #print("do_checkpoint")
        arg={k:v for k, v in arg_arrays.items() if k not in input_shapes}
        aux = dict(zip(network.list_auxiliary_states(), exe.aux_arrays))
        mx.model.save_checkpoint(prefix, epoch, network, arg, aux)
        
        
    #compute valid loss per epoch    
    metric.reset()
    for batch in valid_iter:        
        data[:] = batch.data[0]       
        label[:] = batch.label[0]
        # predict
        outputs = exe.forward(is_train=False)
        Es_valid.append(outputs[1].asnumpy()[0])
        metric.update(batch.label[0], exe.outputs[0])
    e=metric.get()
    err_valid=-e[1][0].asnumpy()[0]
    err_valid2=-e[1][1].asnumpy()[0]
    end = time.time()
    print('time:',end-start,'Epoch:',epoch,'trainloss:',err_train,'validloss:',err_valid,'trainloss2:',err_train2,'validloss2:',err_valid2)
    trainlosses.append(err_train)
    validlosses.append(err_valid)
    trainlosses2.append(err_train2)
    validlosses2.append(err_valid2)
    #print('time:',end-start,'Epoch:',epoch,'trainloss:',err_train,'validloss:',err_valid,'trainloss2',outputs[1].asnumpy())

    #print('time:',end-start,'Epoch:',epoch,'trainloss:',err_train,'validloss:',err_valid)
    #for x,y in zip(e[0],e[1]):
      #print(x,y[0].asnumpy()[0], end=", ", flush=True)
# Out:
# time: 110.52541446685791 Epoch: 60 trainloss: -0.204596 validloss: -0.198664 trainloss2: -0.058357 validloss2: -0.0624751
# time: 110.38817000389099 Epoch: 61 trainloss: -0.20437 validloss: -0.198917 trainloss2: -0.0583498 validloss2: -0.0623945
# time: 110.3494827747345 Epoch: 62 trainloss: -0.20461 validloss: -0.198799 trainloss2: -0.0583538 validloss2: -0.0623439
# time: 110.49287223815918 Epoch: 63 trainloss: -0.204421 validloss: -0.199118 trainloss2: -0.0584741 validloss2: -0.0622366
# time: 110.37884855270386 Epoch: 64 trainloss: -0.204642 validloss: -0.199179 trainloss2: -0.0581918 validloss2: -0.0623039
# time: 110.40162420272827 Epoch: 65 trainloss: -0.204781 validloss: -0.198852 trainloss2: -0.0583157 validloss2: -0.0622665
# time: 110.50672388076782 Epoch: 66 trainloss: -0.204897 validloss: -0.199047 trainloss2: -0.0580334 validloss2: -0.0622214
# time: 110.3656210899353 Epoch: 67 trainloss: -0.204588 validloss: -0.198908 trainloss2: -0.0586318 validloss2: -0.0621476
# time: 110.43701076507568 Epoch: 68 trainloss: -0.20483 validloss: -0.199154 trainloss2: -0.0580344 validloss2: -0.0621964
# time: 110.44166779518127 Epoch: 69 trainloss: -0.204883 validloss: -0.199661 trainloss2: -0.0584187 validloss2: -0.0621073
# time: 110.48901629447937 Epoch: 70 trainloss: -0.204694 validloss: -0.199742 trainloss2: -0.0583678 validloss2: -0.0620429
# time: 110.52093863487244 Epoch: 71 trainloss: -0.204897 validloss: -0.199632 trainloss2: -0.0586579 validloss2: -0.0620434
# time: 110.41992783546448 Epoch: 72 trainloss: -0.205038 validloss: -0.199569 trainloss2: -0.05815 validloss2: -0.0620082
# time: 110.43971943855286 Epoch: 73 trainloss: -0.20523 validloss: -0.199589 trainloss2: -0.0581658 validloss2: -0.0619961
# time: 110.43174934387207 Epoch: 74 trainloss: -0.205272 validloss: -0.199595 trainloss2: -0.0579987 validloss2: -0.06191
# time: 110.50979804992676 Epoch: 75 trainloss: -0.205234 validloss: -0.199456 trainloss2: -0.0579793 validloss2: -0.0619344
# time: 110.433269739151 Epoch: 76 trainloss: -0.205296 validloss: -0.200187 trainloss2: -0.0581467 validloss2: -0.0618354
# time: 110.56732749938965 Epoch: 77 trainloss: -0.205451 validloss: -0.199898 trainloss2: -0.0578788 validloss2: -0.0617933
# time: 110.44296431541443 Epoch: 78 trainloss: -0.205331 validloss: -0.200432 trainloss2: -0.057975 validloss2: -0.0618906
# time: 110.39868974685669 Epoch: 79 trainloss: -0.205555 validloss: -0.200422 trainloss2: -0.0578419 validloss2: -0.0617724
# time: 110.48328900337219 Epoch: 80 trainloss: -0.205994 validloss: -0.200377 trainloss2: -0.0576675 validloss2: -0.061738

# %%
#plot the loss over epoch
Es_train = np.array(Es_train)
Es_train2 = Es_train.reshape((-1,nb))
Es_train3.extend([e for e in list(np.mean(Es_train2,axis=1))])
#plot the loss over epoch
Es_valid = np.array(Es_valid)
Es_valid2 = Es_valid.reshape((-1,nb2))
Es_valid3.extend([e for e in list(np.mean(Es_valid2,axis=1))])
plt.figure()
plt.plot(Es_train3,'.-')
plt.plot(Es_valid3,'.-r')
plt.figure()
plt.plot(trainlosses2,'.-')
plt.plot(validlosses2,'.-r')

# %%
epoch_r  = 80
epoch_r
Es_train=[]
Es_valid=[]
for epoch in range(epoch_r,epoch_r+epochs+1):

    start = time.time()

    metric.reset()

    train_iter.reset()
    
    valid_iter.reset()
    

    for batch in train_iter:
        # Copy data to executor input. Note the [:].
        data[:] = batch.data[0]
        label[:] = batch.label[0]

        # Forward
        outputs=exe.forward(is_train=True)
        Es_train.append(outputs[1].asnumpy()[0])
        # Backward
        exe.backward()

        # Update
        for i, pair in enumerate(zip(exe.arg_arrays, exe.grad_arrays)):
            weight, grad = pair
            updater(i, grad, weight)   
        metric.update(batch.label[0], exe.outputs[0])#metric.update(label,p)
        
    e=metric.get()
    err_train=-e[1][0].asnumpy()[0]
    err_train2=-e[1][1].asnumpy()[0]
    
    if epoch % 10== 0:       
        #print("do_checkpoint")
        arg={k:v for k, v in arg_arrays.items() if k not in input_shapes}
        aux = dict(zip(network.list_auxiliary_states(), exe.aux_arrays))
        mx.model.save_checkpoint(prefix, epoch, network, arg, aux)
        
        
    #compute valid loss per epoch    
    metric.reset()
    for batch in valid_iter:        
        data[:] = batch.data[0]       
        label[:] = batch.label[0]
        # predict
        outputs = exe.forward(is_train=False)
        Es_valid.append(outputs[1].asnumpy()[0])
        metric.update(batch.label[0], exe.outputs[0])
    e=metric.get()
    err_valid=-e[1][0].asnumpy()[0]
    err_valid2=-e[1][1].asnumpy()[0]
    end = time.time()
    print('time:',end-start,'Epoch:',epoch,'trainloss:',err_train,'validloss:',err_valid,'trainloss2:',err_train2,'validloss2:',err_valid2)
    trainlosses.append(err_train)
    validlosses.append(err_valid)
    trainlosses2.append(err_train2)
    validlosses2.append(err_valid2)
    #print('time:',end-start,'Epoch:',epoch,'trainloss:',err_train,'validloss:',err_valid,'trainloss2',outputs[1].asnumpy())

    #print('time:',end-start,'Epoch:',epoch,'trainloss:',err_train,'validloss:',err_valid)
    #for x,y in zip(e[0],e[1]):
      #print(x,y[0].asnumpy()[0], end=", ", flush=True)
# Out:
# time: 110.70681619644165 Epoch: 80 trainloss: -0.205625 validloss: -0.200346 trainloss2: -0.0577104 validloss2: -0.0617553
# time: 110.54930329322815 Epoch: 81 trainloss: -0.205815 validloss: -0.200808 trainloss2: -0.058119 validloss2: -0.0616742
# time: 110.56828022003174 Epoch: 82 trainloss: -0.205703 validloss: -0.20068 trainloss2: -0.0578835 validloss2: -0.0616899
# time: 110.6744954586029 Epoch: 83 trainloss: -0.205941 validloss: -0.200598 trainloss2: -0.0577363 validloss2: -0.0616036
# time: 110.58816337585449 Epoch: 84 trainloss: -0.206304 validloss: -0.200945 trainloss2: -0.0574375 validloss2: -0.0617182
# time: 110.58487725257874 Epoch: 85 trainloss: -0.206033 validloss: -0.200852 trainloss2: -0.0577981 validloss2: -0.0615514
# time: 110.63243055343628 Epoch: 86 trainloss: -0.2062 validloss: -0.201172 trainloss2: -0.0575691 validloss2: -0.0614547
# time: 110.59287309646606 Epoch: 87 trainloss: -0.206319 validloss: -0.201349 trainloss2: -0.0575922 validloss2: -0.06146
# time: 110.65522193908691 Epoch: 88 trainloss: -0.206385 validloss: -0.201326 trainloss2: -0.0576205 validloss2: -0.0614257
# time: 110.59340620040894 Epoch: 89 trainloss: -0.20657 validloss: -0.200756 trainloss2: -0.0574804 validloss2: -0.0613673
# time: 110.77100682258606 Epoch: 90 trainloss: -0.206392 validloss: -0.201817 trainloss2: -0.0574552 validloss2: -0.0614477
# time: 110.52892136573792 Epoch: 91 trainloss: -0.206743 validloss: -0.201262 trainloss2: -0.0573616 validloss2: -0.0613754
# time: 110.59509754180908 Epoch: 92 trainloss: -0.20672 validloss: -0.201322 trainloss2: -0.0573972 validloss2: -0.0613458
# time: 110.61265969276428 Epoch: 93 trainloss: -0.206972 validloss: -0.201677 trainloss2: -0.0572182 validloss2: -0.0613915
# time: 110.60110998153687 Epoch: 94 trainloss: -0.206528 validloss: -0.202297 trainloss2: -0.0575899 validloss2: -0.0614533
# time: 110.58674716949463 Epoch: 95 trainloss: -0.20697 validloss: -0.202025 trainloss2: -0.0575806 validloss2: -0.06133
# time: 110.59240460395813 Epoch: 96 trainloss: -0.206915 validloss: -0.201359 trainloss2: -0.0574454 validloss2: -0.0612383
# time: 110.68091607093811 Epoch: 97 trainloss: -0.206949 validloss: -0.201864 trainloss2: -0.0575496 validloss2: -0.0612067
# time: 110.68296074867249 Epoch: 98 trainloss: -0.207214 validloss: -0.202162 trainloss2: -0.057424 validloss2: -0.0612806
# time: 110.51499223709106 Epoch: 99 trainloss: -0.207343 validloss: -0.202242 trainloss2: -0.0572216 validloss2: -0.0611958
# time: 110.7013099193573 Epoch: 100 trainloss: -0.207297 validloss: -0.202167 trainloss2: -0.0573214 validloss2: -0.0611349

# %%
#plot the loss over epoch
Es_train = np.array(Es_train)
Es_train2 = Es_train.reshape((-1,nb))
Es_train3.extend([e for e in list(np.mean(Es_train2,axis=1))])
#plot the loss over epoch
Es_valid = np.array(Es_valid)
Es_valid2 = Es_valid.reshape((-1,nb2))
Es_valid3.extend([e for e in list(np.mean(Es_valid2,axis=1))])
plt.figure()
plt.plot(Es_train3,'.-')
plt.plot(Es_valid3,'.-r')
plt.figure()
plt.plot(trainlosses2,'.-')
plt.plot(validlosses2,'.-r')

# %%
epoch_r  = 100
epoch_r
Es_train=[]
Es_valid=[]
for epoch in range(epoch_r,epoch_r+epochs+1):

    start = time.time()

    metric.reset()

    train_iter.reset()
    
    valid_iter.reset()
    

    for batch in train_iter:
        # Copy data to executor input. Note the [:].
        data[:] = batch.data[0]
        label[:] = batch.label[0]

        # Forward
        outputs=exe.forward(is_train=True)
        Es_train.append(outputs[1].asnumpy()[0])
        # Backward
        exe.backward()

        # Update
        for i, pair in enumerate(zip(exe.arg_arrays, exe.grad_arrays)):
            weight, grad = pair
            updater(i, grad, weight)   
        metric.update(batch.label[0], exe.outputs[0])#metric.update(label,p)
        
    e=metric.get()
    err_train=-e[1][0].asnumpy()[0]
    err_train2=-e[1][1].asnumpy()[0]
    
    if epoch % 10== 0:       
        #print("do_checkpoint")
        arg={k:v for k, v in arg_arrays.items() if k not in input_shapes}
        aux = dict(zip(network.list_auxiliary_states(), exe.aux_arrays))
        mx.model.save_checkpoint(prefix, epoch, network, arg, aux)
        
        
    #compute valid loss per epoch    
    metric.reset()
    for batch in valid_iter:        
        data[:] = batch.data[0]       
        label[:] = batch.label[0]
        # predict
        outputs = exe.forward(is_train=False)
        Es_valid.append(outputs[1].asnumpy()[0])
        metric.update(batch.label[0], exe.outputs[0])
    e=metric.get()
    err_valid=-e[1][0].asnumpy()[0]
    err_valid2=-e[1][1].asnumpy()[0]
    end = time.time()
    print('time:',end-start,'Epoch:',epoch,'trainloss:',err_train,'validloss:',err_valid,'trainloss2:',err_train2,'validloss2:',err_valid2)
    trainlosses.append(err_train)
    validlosses.append(err_valid)
    trainlosses2.append(err_train2)
    validlosses2.append(err_valid2)
    #print('time:',end-start,'Epoch:',epoch,'trainloss:',err_train,'validloss:',err_valid,'trainloss2',outputs[1].asnumpy())

    #print('time:',end-start,'Epoch:',epoch,'trainloss:',err_train,'validloss:',err_valid)
    #for x,y in zip(e[0],e[1]):
      #print(x,y[0].asnumpy()[0], end=", ", flush=True)
# Out:
# time: 110.62810039520264 Epoch: 100 trainloss: -0.207436 validloss: -0.202196 trainloss2: -0.0573159 validloss2: -0.0611021
# time: 110.7623519897461 Epoch: 101 trainloss: -0.207284 validloss: -0.20209 trainloss2: -0.0572412 validloss2: -0.0610923
# time: 110.61424279212952 Epoch: 102 trainloss: -0.207719 validloss: -0.202707 trainloss2: -0.0568983 validloss2: -0.0610692
# time: 110.71409869194031 Epoch: 103 trainloss: -0.207815 validloss: -0.202083 trainloss2: -0.0570092 validloss2: -0.0610601
# time: 110.73068380355835 Epoch: 104 trainloss: -0.207498 validloss: -0.202431 trainloss2: -0.0570057 validloss2: -0.0609749
# time: 110.7099609375 Epoch: 105 trainloss: -0.207586 validloss: -0.202213 trainloss2: -0.057162 validloss2: -0.0609891
# time: 110.72011637687683 Epoch: 106 trainloss: -0.207461 validloss: -0.202113 trainloss2: -0.0568925 validloss2: -0.0609151
# time: 110.7358546257019 Epoch: 107 trainloss: -0.207792 validloss: -0.20265 trainloss2: -0.0572297 validloss2: -0.0608926
# time: 110.70029926300049 Epoch: 108 trainloss: -0.207902 validloss: -0.20284 trainloss2: -0.056986 validloss2: -0.0609263
# time: 110.54325461387634 Epoch: 109 trainloss: -0.208014 validloss: -0.20279 trainloss2: -0.0568406 validloss2: -0.06084
# time: 110.80075812339783 Epoch: 110 trainloss: -0.207859 validloss: -0.202764 trainloss2: -0.0571642 validloss2: -0.0608641
# time: 110.70147204399109 Epoch: 111 trainloss: -0.207869 validloss: -0.203519 trainloss2: -0.0568336 validloss2: -0.0608038
# time: 110.77948713302612 Epoch: 112 trainloss: -0.208172 validloss: -0.203644 trainloss2: -0.0569219 validloss2: -0.0607357
# time: 110.64302468299866 Epoch: 113 trainloss: -0.208041 validloss: -0.203072 trainloss2: -0.0569415 validloss2: -0.0607348
# time: 110.77780413627625 Epoch: 114 trainloss: -0.208231 validloss: -0.203741 trainloss2: -0.0570897 validloss2: -0.0607551
# time: 110.7107355594635 Epoch: 115 trainloss: -0.208534 validloss: -0.203331 trainloss2: -0.0566287 validloss2: -0.060787
# time: 110.69165062904358 Epoch: 116 trainloss: -0.208422 validloss: -0.203356 trainloss2: -0.0566646 validloss2: -0.0606658
# time: 110.60405707359314 Epoch: 117 trainloss: -0.208494 validloss: -0.203894 trainloss2: -0.0567895 validloss2: -0.0606057
# time: 110.59909296035767 Epoch: 118 trainloss: -0.208477 validloss: -0.204031 trainloss2: -0.0566498 validloss2: -0.060552
# time: 110.74066805839539 Epoch: 119 trainloss: -0.208401 validloss: -0.203728 trainloss2: -0.0571911 validloss2: -0.0605236
# time: 110.5732798576355 Epoch: 120 trainloss: -0.208487 validloss: -0.203353 trainloss2: -0.0569855 validloss2: -0.0605267

# %%
#plot the loss over epoch
Es_train = np.array(Es_train)
Es_train2 = Es_train.reshape((-1,nb))
Es_train3.extend([e for e in list(np.mean(Es_train2,axis=1))])
#plot the loss over epoch
Es_valid = np.array(Es_valid)
Es_valid2 = Es_valid.reshape((-1,nb2))
Es_valid3.extend([e for e in list(np.mean(Es_valid2,axis=1))])
plt.figure()
plt.plot(Es_train3,'.-')
plt.plot(Es_valid3,'.-r')
plt.figure()
plt.plot(trainlosses2,'.-')
plt.plot(validlosses2,'.-r')
