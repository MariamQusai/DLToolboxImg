# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
logfile = "errorlogmodel10.csv"
model_path = "drive/My Drive/x110/model/model10/errorlogmodel10_3.csv"

# %%
df = pd.read_csv(model_path, index_col=0,names=col_names)
df.head()
# Out:
#    epoch     lr      loss   E1train   E1valid   E2train   E2valid
# 0     84  0.015 -0.730272 -0.622463 -0.579282  0.174106  0.261012
# 0     85  0.015 -0.749008 -0.621706 -0.586055  0.171213  0.248653
# 0     86  0.015 -0.741522 -0.619181 -0.576656  0.168777  0.243020
# 0     87  0.015 -0.748999 -0.623053 -0.599727  0.167032  0.231447
# 0     88  0.015 -0.740545 -0.619613 -0.584323  0.159398  0.229434

# %%
#df = pd.read_csv(logfile, index_col=0)
df['epoch'] = [i for i in range(df.shape[0])]
plt.figure()
plt.plot(df['epoch'],df['lr'])
plt.title('Learning Rate')
plt.figure()
plt.plot(df['epoch'],df['E1train'])
plt.plot(df['epoch'],df['E1valid'],'r')
plt.title('E1')
#plt.figure()
#plt.plot(df['epoch'],df['E2train'])
#plt.plot(df['epoch'],df['E2valid'],'r')
#plt.title('E2')
# Out:
# Text(0.5,1,'E1')

# %%
df = pd.read_csv(logfile, index_col=0)
df['epoch'] = [i for i in range(83,83+df.shape[0])]
plt.figure()
plt.plot(df['epoch'],df['lr'])
plt.title('Learning Rate')
plt.figure()
plt.plot(df['epoch'],df['E1train'])
plt.plot(df['epoch'],df['E1valid'],'r')
plt.title('E1')
#plt.figure()
#plt.plot(df['epoch'],df['E2train'])
#plt.plot(df['epoch'],df['E2valid'],'r')
#plt.title('E2')

# %%
#df.to_csv(model_path, header=False)
