# %% [markdown]
# <a href="https://colab.research.google.com/github/x110/DLToolboxImg/blob/master/monitor_performance_while_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
logfile = "errorlogmodel10.csv"
model_path = "drive/My Drive/x110/model/model10/errorlogmodel10.csv"

# %%
df = pd.read_csv(logfile, index_col=0)

plt.figure()
plt.plot(df['epoch'],df['lr'])
plt.title('Learning Rate')
plt.figure()
plt.plot(df['epoch'],df['E1train'])
plt.plot(df['epoch'],df['E1valid'],'r')
plt.title('E1')
#plt.figure()
#plt.plot(df['epoch'],df['E2train'])
#plt.plot(df['epoch'],df['E2valid'],'r')
#plt.title('E2')
# Out:
# Text(0.5,1,'E1')

# %%
df = pd.read_csv(logfile, index_col=0)
df['epoch'] = [i for i in range(83,83+df.shape[0])]
plt.figure()
plt.plot(df['epoch'],df['lr'])
plt.title('Learning Rate')
plt.figure()
plt.plot(df['epoch'],df['E1train'])
plt.plot(df['epoch'],df['E1valid'],'r')
plt.title('E1')
#plt.figure()
#plt.plot(df['epoch'],df['E2train'])
#plt.plot(df['epoch'],df['E2valid'],'r')
#plt.title('E2')
# Out:
# Text(0.5,1,'E1')

# %%
df.to_csv(model_path, header=False)

# %%
df.to_csv(model_path, header=False)
